# %%
import numpy as np

# %%
n = 100
mat = np.ones((n, n), dtype='int8')
for n in range(1, n // 2 + 1):
    mat[n:-n, n:-n] = n + 1
print(mat)
# Out:
# [[1 1 1 ... 1 1 1]
#  [1 2 2 ... 2 2 1]
#  [1 2 3 ... 3 2 1]
#  ...
#  [1 2 3 ... 3 2 1]
#  [1 2 2 ... 2 2 1]
#  [1 1 1 ... 1 1 1]]

# %%
import matplotlib.pyplot as plt
plt.imshow(mat, cmap='Reds')
