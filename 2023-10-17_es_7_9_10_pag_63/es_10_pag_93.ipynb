# %%
import numpy as np

# %%
values = np.random.normal(19, 5, 1000)

for i in range(20):
    i = np.random.randint(0, len(values))
    values[i] = 9999.99
values
# Out:
# array([1.45780807e+01, 2.37471274e+01, 2.40403226e+01, 2.02522202e+01,
#        1.89905720e+01, 1.10290068e+01, 1.40568961e+01, 8.44758078e+00,
#        1.23417947e+01, 2.27383861e+01, 2.13667673e+01, 2.32872956e+01,
#        1.12612673e+01, 1.98877731e+01, 1.38943995e+01, 2.93760330e+01,
#        1.61648441e+01, 1.93774605e+01, 1.70861366e+01, 1.91931769e+01,
#        1.73134610e+01, 1.21109786e+01, 1.71119186e+01, 1.92157033e+01,
#        1.66937662e+01, 1.98245626e+01, 1.94957902e+01, 2.12445481e+01,
#        1.34346855e+01, 1.84159803e+01, 1.75591624e+01, 2.32899017e+01,
#        1.81182824e+01, 9.93416094e+00, 1.63207169e+01, 1.67700320e+01,
#        2.58894923e+01, 2.18101391e+01, 1.14570294e+01, 1.68061693e+01,
#        2.36371336e+01, 2.28478528e+01, 1.34270494e+01, 1.08119578e+01,
#        1.57068260e+01, 1.61248754e+01, 1.19530604e+01, 2.74901672e+01,
#        1.54054103e+01, 1.64705115e+01, 1.70947955e+01, 1.57596952e+01,
# ...

# %%
np.count_nonzero(values > 9999)
# Out:
# 18
