# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size = 100
lato_q = 10

# %%
scacchiera = np.zeros((size, size))
for n in range(0, size // lato_q, 2):
    scacchiera[n * lato_q:(n + 1) * lato_q, 0:lato_q] = 255
plt.imshow(scacchiera)
